# %% [markdown]
# # mapas

# %%
# 2. Plotly - Mapas interactivos avanzados

import plotly.graph_objects as go
import plotly.express as px

# Mapa con marcadores
fig = go.Figure(go.Scattermapbox(
    lat=[4.6097],
    lon=[-74.0817],
    mode='markers',
    marker=dict(size=14, color='red'),
    text=['Bogotá'],
))

fig.update_layout(
    mapbox_style="open-street-map",
    mapbox=dict(center=dict(lat=4.6097, lon=-74.0817), zoom=10),
    margin={"r":0,"t":0,"l":0,"b":0}
)
# Out:
# C:\Users\aprendiz\AppData\Local\Temp\ipykernel_16520\4118552962.py:7: DeprecationWarning: *scattermapbox* is deprecated! Use *scattermap* instead. Learn more at: https://plotly.com/python/mapbox-to-maplibre/
#   fig = go.Figure(go.Scattermapbox(

# %%
# 1. folium - la mas popular y facial 
import folium

# mapa basico
m = folium.Map(location=[4.6097, -74.0817], zoom_start=10) #bogotá
m.save('mapa.html')
m # en jupyter se muestra directamente
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2ff231aba88a3ed7e1bbb967a79161c0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2ff231aba88a3ed7e1bbb967a79161c0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2ff231aba88a3ed7e1bbb967a79161c0 = L.map(
#                 &quot;map_2ff231aba88a3ed7e1bbb967a79161c0&quot;,
#                 {
#                     center: [4.6097, -74.0817],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_82fb1c9c238af7eb28a7f4a6d850f5fe = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_82fb1c9c238af7eb28a7f4a6d850f5fe.addTo(map_2ff231aba88a3ed7e1bbb967a79161c0);
#
#
#             tile_layer_82fb1c9c238af7eb28a7f4a6d850f5fe.addTo(map_2ff231aba88a3ed7e1bbb967a79161c0);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
## 2. Folium

import folium

# Mapa básico de Colombia
m = folium.Map(location=[4.6, -74.08], zoom_start=6)

# Agregar marcadores de ciudades principales
ciudades = {
    'Bogotá': [4.6097, -74.0817],
    'Medellín': [6.2442, -75.5812],
    'Cali': [3.4516, -76.5320],
    'Barranquilla': [10.9685, -74.7813],
    'Cartagena': [10.3910, -75.4794],
    'Santa marta': [11.2408, -74.2009],
    'Bucaramanga': [7.1254, -73.1193]
}

for ciudad, coords in ciudades.items():
    folium.Marker(
        coords,
        popup=ciudad,
        tooltip=ciudad,
        icon=folium.Icon(color='red', icon='info-sign')
    ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_645222a99dbdbfee482cf8a1a8200dbe {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_645222a99dbdbfee482cf8a1a8200dbe&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_645222a99dbdbfee482cf8a1a8200dbe = L.map(
#                 &quot;map_645222a99dbdbfee482cf8a1a8200dbe&quot;,
#                 {
#                     center: [4.6, -74.08],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bb8d4b4efabbe63987517dc4b34c0f3b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_bb8d4b4efabbe63987517dc4b34c0f3b.addTo(map_645222a99dbdbfee482cf8a1a8200dbe);
#
#
#             var marker_5e696257b35d0c4c318336f156451bf3 = L.marker(
#                 [4.6097, -74.0817],
#                 {
# }
#             ).addTo(map_645222a99dbdbfee482cf8a1a8200dbe);
#
#
#             var icon_6c07f8df3fc8ebaf42fe485103ae2a47 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_a2a5d18e628e06f57269ab3afe770775 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f47454d3b60d719ae88e392643e48edd = $(`&lt;div id=&quot;html_f47454d3b60d719ae88e392643e48edd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bogotá&lt;/div&gt;`)[0];
#                 popup_a2a5d18e628e06f57269ab3afe770775.setContent(html_f47454d3b60d719ae88e392643e48edd);
#
#
#
#         marker_5e696257b35d0c4c318336f156451bf3.bindPopup(popup_a2a5d18e628e06f57269ab3afe770775)
#         ;
#
#
#
#
#             marker_5e696257b35d0c4c318336f156451bf3.bindTooltip(
#                 `&lt;div&gt;
#                      Bogotá
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_5e696257b35d0c4c318336f156451bf3.setIcon(icon_6c07f8df3fc8ebaf42fe485103ae2a47);
#
#
#             var marker_3d04050d0d2144e2ada55b28b35c914d = L.marker(
#                 [6.2442, -75.5812],
#                 {
# }
#             ).addTo(map_645222a99dbdbfee482cf8a1a8200dbe);
#
#
#             var icon_bd0229ef13677c7f4e41be54a7dea715 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_963fb65d9a65ce33009d2c94c8011398 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f33f7b6988b5c77e0cd0005800a0f7f6 = $(`&lt;div id=&quot;html_f33f7b6988b5c77e0cd0005800a0f7f6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Medellín&lt;/div&gt;`)[0];
#                 popup_963fb65d9a65ce33009d2c94c8011398.setContent(html_f33f7b6988b5c77e0cd0005800a0f7f6);
#
#
#
#         marker_3d04050d0d2144e2ada55b28b35c914d.bindPopup(popup_963fb65d9a65ce33009d2c94c8011398)
#         ;
#
#
#
#
#             marker_3d04050d0d2144e2ada55b28b35c914d.bindTooltip(
#                 `&lt;div&gt;
#                      Medellín
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_3d04050d0d2144e2ada55b28b35c914d.setIcon(icon_bd0229ef13677c7f4e41be54a7dea715);
#
#
#             var marker_27b829ad1ed0a88ad98066914568cb4e = L.marker(
#                 [3.4516, -76.532],
#                 {
# }
#             ).addTo(map_645222a99dbdbfee482cf8a1a8200dbe);
#
#
#             var icon_35bae2d451c31fa6460115a36444d1bb = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_19dd144180138ad6278f18f1f3129859 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_84667fffdaa15a777478231ca68ee1ac = $(`&lt;div id=&quot;html_84667fffdaa15a777478231ca68ee1ac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cali&lt;/div&gt;`)[0];
